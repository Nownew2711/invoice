# %%
import gradio as gr
from pdf2image import convert_from_path
import pytesseract
import pandas as pd
import re
import os
import logging
from supabase import create_client, Client

# Initialize Supabase client
url = "https://qumfinzjetrdhzmbuwcz.supabase.co" #"your_supabase_url"
key = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6InF1bWZpbnpqZXRyZGh6bWJ1d2N6Iiwicm9sZSI6ImFub24iLCJpYXQiOjE3MjM3ODU2NTUsImV4cCI6MjAzOTM2MTY1NX0.e8SwMVAOEILIgWk4QaJu0STayCur7uyJEnMXBNUxadg" #"your_supabase_key"

supabase: Client = create_client(url, key)

# Define the Supabase logging handler
class SupabaseHandler(logging.Handler):
    def emit(self, record):
        log_entry = self.format(record)
        # Insert log entry into Supabase
        data = {
            "level": record.levelname,
            "message": log_entry,
            "file_name": record.pathname  # Add more fields if needed
        }
        supabase.table("logs").insert(data).execute()

# Configure logging to use both file and Supabase
supabase_handler = SupabaseHandler()
logging.basicConfig(
    level=logging.ERROR ,  # Change from DEBUG to WARNING
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler('process_log.log'),
        supabase_handler
    ]
)


def process_pdf(file):
    try:
        logging.info(f"Processing file: {file.name}")

        # Check if the file is a PDF
        if not file.name.lower().endswith('.pdf'):
            logging.warning("Uploaded file is not a PDF.")
            return "Error: Uploaded file is not a PDF. Please upload a PDF file.", None
        
        # Convert PDF to images
        images = convert_from_path(file.name)
        logging.info(f"PDF converted to {len(images)} image(s).")

        full_text = ""
        for i, img in enumerate(images):
            text = pytesseract.image_to_string(img)
            logging.debug(f"Text extracted from image {i+1}: {text[:100]}...")
            full_text += text + "\n"
        
        # If no text was extracted, likely a wrong or empty PDF
        if not full_text.strip():
            logging.error("No text could be extracted from the PDF.")
            return "Error: Unable to extract text. The PDF might be blank or incorrectly formatted.", None

        # Check for required keywords
        required_keywords = ['invoice', 'order no', 'invoice date', 'supplier name', 'warehouse id']
        if not any(keyword in full_text.lower() for keyword in required_keywords):
            logging.warning("Necessary keywords not found in the PDF.")
            return "Error: The uploaded PDF does not contain necessary fields like 'Invoice', 'Order No', etc. Please upload a correct invoice.", None
        
        # Save extracted data to CSV
        csv_data = save_to_csv(full_text)
        csv_path = "output.csv"  # Specify the output CSV file name
        with open(csv_path, "w") as f:
            f.write(csv_data)  # Write the CSV data to the file

        logging.info("Processing completed successfully.")
        return "Processing Complete", csv_path  # Return the file path

    except Exception as e:
        logging.error(f"An unexpected error occurred: {str(e)}")
        return f"Error: An unexpected error occurred: {str(e)}", None

def extract_fields(text):
    logging.debug("Extracting fields from text.")
    invoice_no = re.search(r'Invoice No:\s*([A-Z0-9-]+)', text)
    order_no = re.search(r'HM Order No:\s*(\d+)', text)
    invoice_date = re.search(r'Invoice Date:\s*([\d-]+)', text)
    supplier_name = re.search(r'Supplier Name:\s*([A-Z\s]+)', text)
    warehouse_id = re.search(r'\bINW\d{3}\b', text)
    
    description_of_goods = None
    if warehouse_id:
        warehouse_line_start = text.find(warehouse_id.group(0))
        description_lines = []
        lines = text[warehouse_line_start:].split('\n')
        for line in lines:
            if "Container No:" in line:
                break
            description_lines.append(line.strip())
        description = ' '.join(description_lines).replace(' Cartons', '')
        words = description.split()
        filtered_words = [
            word for word in words
            if not re.match(r'^\d+(\.\d+)?$', word) and word.lower() not in ['usd', 'pieces'] and '=' not in word
        ]
        description_of_goods = ' '.join(filtered_words)

    logging.debug(f"Fields extracted: Invoice No: {invoice_no}, Order No: {order_no}, Invoice Date: {invoice_date}, Supplier Name: {supplier_name}, Warehouse ID: {warehouse_id}")
    return {
        'Invoice No': invoice_no.group(1) if invoice_no else None,
        'HM Order No': order_no.group(1) if order_no else None,
        'Invoice Date': invoice_date.group(1) if invoice_date else None,
        'Supplier Name': supplier_name.group(1).strip() if supplier_name else None,
        'Warehouse ID': warehouse_id.group(0) if warehouse_id else None,
        'Description of Goods': description_of_goods
    }

def save_to_csv(full_text):
    logging.info("Saving extracted fields to CSV.")
    invoice_texts = full_text.split('INVOICE')
    data = []

    for i in range(1, len(invoice_texts)):
        invoice_text = "INVOICE" + invoice_texts[i]
        fields = extract_fields(invoice_text)
        if fields['Invoice No']:
            data.append(fields)
    
    df_invoices = pd.DataFrame(data)
    
    # Function to fix hanging words and capitalize text
    def fix_description(description):
        words = description.split()
        fixed_words = []
        for i in range(len(words) - 1):
            if len(words[i + 1]) <= 2:
                fixed_words.append(words[i] + words[i + 1])
            else:
                if len(words[i]) > 2:
                    fixed_words.append(words[i])
        if len(words[-1]) > 1:
            fixed_words.append(words[-1])

        return " ".join(fixed_words).upper()

    df_invoices['Description of Goods'] = df_invoices['Description of Goods'].apply(fix_description)

    csv_data = df_invoices.to_csv(index=False)
    logging.info("CSV file created successfully.")
    return csv_data

iface = gr.Interface(
    fn=process_pdf,
    inputs=gr.File(file_types=['.pdf']),
    outputs=[gr.Textbox(), gr.File(label="Download CSV")]
)

iface.launch()
# Out:
# 2024-08-16 22:18:20,368:INFO - HTTP Request: GET http://127.0.0.1:7867/startup-events "HTTP/1.1 200 OK"
# Running on local URL:  http://127.0.0.1:7867
# 2024-08-16 22:18:20,772:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:20,930:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:21,094:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:21,246:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:21,338:INFO - HTTP Request: GET https://api.gradio.app/pkg-version "HTTP/1.1 200 OK"
# 2024-08-16 22:18:21,405:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:21,553:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:21,706:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:21,856:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:22,044:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:22,214:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:22,363:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:22,517:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:22,679:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:22,829:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:22,989:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:23,159:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:23,308:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:23,463:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:23,610:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:23,761:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:23,934:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:24,090:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:24,240:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:24,391:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:24,545:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:24,698:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:24,852:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:25,016:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:25,179:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:25,334:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:25,487:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:25,786:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 158
#     150     return csv_data
#     152 iface = gr.Interface(
#     153     fn=process_pdf,
#     154     inputs=gr.File(file_types=['.pdf']),
#     155     outputs=[gr.Textbox(), gr.File(label="Download CSV")]
#     156 )
# --> 158 iface.launch()
#
# File ~/.local/lib/python3.10/site-packages/gradio/blocks.py:2399, in Blocks.launch(self, inline, inbrowser, share, debug, max_threads, auth, auth_message, prevent_thread_lock, show_error, server_name, server_port, height, width, favicon_path, ssl_keyfile, ssl_certfile, ssl_keyfile_password, ssl_verify, quiet, show_api, allowed_paths, blocked_paths, root_path, app_kwargs, state_session_capacity, share_server_address, share_server_protocol, auth_dependency, max_file_size, _frontend, enable_monitoring)
#    2394 self._queue.set_server_app(self.server_app)
#    2396 if not wasm_utils.IS_WASM:
#    2397     # Cannot run async functions in background other than app's scope.
#    2398     # Workaround by triggering the app endpoint
# -> 2399     httpx.get(
#    2400         f"{self.local_url}startup-events", verify=ssl_verify, timeout=None
#    2401     )
#    2402 else:
#    2403     # NOTE: One benefit of the code above dispatching `startup_events()` via a self HTTP request is
#    2404     # that `self._queue.start()` is called in another thread which is managed by the HTTP server, `uvicorn`
#    (...)
#    2407     # In contrast, in the Wasm env, we can't do that because `threading` is not supported and all async tasks will run in the same event loop, `pyodide.webloop.WebLoop` in the main thread.
#    2408     # So we need to manually cancel them. See `self.close()`..
#    2409     self.startup_events()
#
# File ~/.local/lib/python3.10/site-packages/httpx/_api.py:189, in get(url, params, headers, cookies, auth, proxies, follow_redirects, cert, verify, timeout, trust_env)
#     167 def get(
#     168     url: URLTypes,
#     169     *,
#    (...)
#     179     trust_env: bool = True,
#     180 ) -> Response:
#     181     """
#     182     Sends a `GET` request.
#     183
#    (...)
#     187     on this function, as `GET` requests should not include a request body.
#     188     """
# --> 189     return request(
#     190         "GET",
#     191         url,
#     192         params=params,
#     193         headers=headers,
#     194         cookies=cookies,
#     195         auth=auth,
#     196         proxies=proxies,
#     197         follow_redirects=follow_redirects,
#     198         cert=cert,
#     199         verify=verify,
#     200         timeout=timeout,
#     201         trust_env=trust_env,
#     202     )
#
# File ~/.local/lib/python3.10/site-packages/httpx/_api.py:100, in request(method, url, params, content, data, files, json, headers, cookies, auth, proxies, timeout, follow_redirects, verify, cert, trust_env)
#      42 """
#      43 Sends an HTTP request.
#      44
#    (...)
#      90 ```
#      91 """
#      92 with Client(
#      93     cookies=cookies,
#      94     proxies=proxies,
#    (...)
#      98     trust_env=trust_env,
#      99 ) as client:
# --> 100     return client.request(
#     101         method=method,
#     102         url=url,
#     103         content=content,
#     104         data=data,
#     105         files=files,
#     106         json=json,
#     107         params=params,
#     108         headers=headers,
#     109         auth=auth,
#     110         follow_redirects=follow_redirects,
#     111     )
#
# File ~/.local/lib/python3.10/site-packages/httpx/_client.py:814, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     799     warnings.warn(message, DeprecationWarning)
#     801 request = self.build_request(
#     802     method=method,
#     803     url=url,
#    (...)
#     812     extensions=extensions,
#     813 )
# --> 814 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~/.local/lib/python3.10/site-packages/httpx/_client.py:901, in Client.send(self, request, stream, auth, follow_redirects)
#     893 follow_redirects = (
#     894     self.follow_redirects
#     895     if isinstance(follow_redirects, UseClientDefault)
#     896     else follow_redirects
#     897 )
#     899 auth = self._build_request_auth(request, auth)
# --> 901 response = self._send_handling_auth(
#     902     request,
#     903     auth=auth,
#     904     follow_redirects=follow_redirects,
#     905     history=[],
#     906 )
#     907 try:
#     908     if not stream:
#
# File ~/.local/lib/python3.10/site-packages/httpx/_client.py:929, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     926 request = next(auth_flow)
#     928 while True:
# --> 929     response = self._send_handling_redirects(
#     930         request,
#     931         follow_redirects=follow_redirects,
#     932         history=history,
#     933     )
#     934     try:
#     935         try:
#
# File ~/.local/lib/python3.10/site-packages/httpx/_client.py:966, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     963 for hook in self._event_hooks["request"]:
#     964     hook(request)
# --> 966 response = self._send_single_request(request)
#     967 try:
#     968     for hook in self._event_hooks["response"]:
#
# File ~/.local/lib/python3.10/site-packages/httpx/_client.py:1013, in Client._send_single_request(self, request)
#    1010 self.cookies.extract_cookies(response)
#    1011 response.default_encoding = self._default_encoding
# -> 1013 logger.info(
#    1014     'HTTP Request: %s %s "%s %d %s"',
#    1015     request.method,
#    1016     request.url,
#    1017     response.http_version,
#    1018     response.status_code,
#    1019     response.reason_phrase,
#    1020 )
#    1022 return response
#
# File /usr/lib/python3.10/logging/__init__.py:1477, in Logger.info(self, msg, *args, **kwargs)
#    1468 """
#    1469 Log 'msg % args' with severity 'INFO'.
#    1470
#    (...)
#    1474 logger.info("Houston, we have a %s", "interesting problem", exc_info=1)
#    1475 """
#    1476 if self.isEnabledFor(INFO):
# -> 1477     self._log(INFO, msg, args, **kwargs)
#
# File /usr/lib/python3.10/logging/__init__.py:1624, in Logger._log(self, level, msg, args, exc_info, extra, stack_info, stacklevel)
#    1621         exc_info = sys.exc_info()
#    1622 record = self.makeRecord(self.name, level, fn, lno, msg, args,
#    1623                          exc_info, func, extra, sinfo)
# -> 1624 self.handle(record)
#
# File /usr/lib/python3.10/logging/__init__.py:1634, in Logger.handle(self, record)
#    1627 """
#    1628 Call the handlers for the specified record.
#    1629
#    1630 This method is used for unpickled records received from a socket, as
#    1631 well as those created locally. Logger-level filtering is applied.
#    1632 """
#    1633 if (not self.disabled) and self.filter(record):
# -> 1634     self.callHandlers(record)
#
# File /usr/lib/python3.10/logging/__init__.py:1696, in Logger.callHandlers(self, record)
#    1694     found = found + 1
#    1695     if record.levelno >= hdlr.level:
# -> 1696         hdlr.handle(record)
#    1697 if not c.propagate:
#    1698     c = None    #break out
#
# File /usr/lib/python3.10/logging/__init__.py:968, in Handler.handle(self, record)
#     966 self.acquire()
#     967 try:
# --> 968     self.emit(record)
#     969 finally:
#     970     self.release()
#
# Cell In[5], line 26, in SupabaseHandler.emit(self, record)
#      19 try:
#      20     # Insert log entry into Supabase
#      21     data = {
#      22         "level": record.levelname,
#      23         "message": log_entry,
#      24         "file_name": record.pathname  # Add more fields if needed
#      25     }
# ---> 26     supabase.table("logs").insert(data).execute()
#      27     print(data)
#      28     print(log_entry)
#
# File ~/.local/lib/python3.10/site-packages/postgrest/_sync/request_builder.py:57, in SyncQueryRequestBuilder.execute(self)
#      45 def execute(self) -> APIResponse[_ReturnT]:
#      46     """Execute the query.
#      47
#      48     .. tip::
#    (...)
#      55         :class:`APIError` If the API raised an error.
#      56     """
# ---> 57     r = self.session.request(
#      58         self.http_method,
#      59         self.path,
#      60         json=self.json,
#      61         params=self.params,
#      62         headers=self.headers,
#      63     )
#      64     try:
#      65         if (
#      66             200 <= r.status_code <= 299
#      67         ):  # Response.ok from JS (https://developer.mozilla.org/en-US/docs/Web/API/Response/ok)
#
# File ~/.local/lib/python3.10/site-packages/httpx/_client.py:814, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     799     warnings.warn(message, DeprecationWarning)
#     801 request = self.build_request(
#     802     method=method,
#     803     url=url,
#    (...)
#     812     extensions=extensions,
#     813 )
# --> 814 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~/.local/lib/python3.10/site-packages/httpx/_client.py:901, in Client.send(self, request, stream, auth, follow_redirects)
#     893 follow_redirects = (
#     894     self.follow_redirects
#     895     if isinstance(follow_redirects, UseClientDefault)
#     896     else follow_redirects
#     897 )
#     899 auth = self._build_request_auth(request, auth)
# --> 901 response = self._send_handling_auth(
#     902     request,
#     903     auth=auth,
#     904     follow_redirects=follow_redirects,
#     905     history=[],
#     906 )
#     907 try:
#     908     if not stream:
#
# File ~/.local/lib/python3.10/site-packages/httpx/_client.py:929, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     926 request = next(auth_flow)
#     928 while True:
# --> 929     response = self._send_handling_redirects(
#     930         request,
#     931         follow_redirects=follow_redirects,
#     932         history=history,
#     933     )
#     934     try:
#     935         try:
#
# File ~/.local/lib/python3.10/site-packages/httpx/_client.py:966, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     963 for hook in self._event_hooks["request"]:
#     964     hook(request)
# --> 966 response = self._send_single_request(request)
#     967 try:
#     968     for hook in self._event_hooks["response"]:
#
# File ~/.local/lib/python3.10/site-packages/httpx/_client.py:1013, in Client._send_single_request(self, request)
#    1010 self.cookies.extract_cookies(response)
#    1011 response.default_encoding = self._default_encoding
# -> 1013 logger.info(
#    1014     'HTTP Request: %s %s "%s %d %s"',
#    1015     request.method,
#    1016     request.url,
#    1017     response.http_version,
#    1018     response.status_code,
#    1019     response.reason_phrase,
#    1020 )
#    1022 return response
#
# File /usr/lib/python3.10/logging/__init__.py:1477, in Logger.info(self, msg, *args, **kwargs)
#    1468 """
#    1469 Log 'msg % args' with severity 'INFO'.
#    1470
#    (...)
#    1474 logger.info("Houston, we have a %s", "interesting problem", exc_info=1)
#    1475 """
#    1476 if self.isEnabledFor(INFO):
# -> 1477     self._log(INFO, msg, args, **kwargs)
#
# File /usr/lib/python3.10/logging/__init__.py:1624, in Logger._log(self, level, msg, args, exc_info, extra, stack_info, stacklevel)
#    1621         exc_info = sys.exc_info()
#    1622 record = self.makeRecord(self.name, level, fn, lno, msg, args,
#    1623                          exc_info, func, extra, sinfo)
# -> 1624 self.handle(record)
#
# File /usr/lib/python3.10/logging/__init__.py:1634, in Logger.handle(self, record)
#    1627 """
#    1628 Call the handlers for the specified record.
#    1629
#    1630 This method is used for unpickled records received from a socket, as
#    1631 well as those created locally. Logger-level filtering is applied.
#    1632 """
#    1633 if (not self.disabled) and self.filter(record):
# -> 1634     self.callHandlers(record)
#
# File /usr/lib/python3.10/logging/__init__.py:1696, in Logger.callHandlers(self, record)
#    1694     found = found + 1
#    1695     if record.levelno >= hdlr.level:
# -> 1696         hdlr.handle(record)
#    1697 if not c.propagate:
#    1698     c = None    #break out
#
# File /usr/lib/python3.10/logging/__init__.py:968, in Handler.handle(self, record)
#     966 self.acquire()
#     967 try:
# --> 968     self.emit(record)
#     969 finally:
#     970     self.release()
#
# Cell In[5], line 26, in SupabaseHandler.emit(self, record)
#      19 try:
#      20     # Insert log entry into Supabase
#      21     data = {
#      22         "level": record.levelname,
#      23         "message": log_entry,
#      24         "file_name": record.pathname  # Add more fields if needed
#      25     }
# ---> 26     supabase.table("logs").insert(data).execute()
#      27     print(data)
#      28     print(log_entry)
#
# File ~/.local/lib/python3.10/site-packages/postgrest/_sync/request_builder.py:57, in SyncQueryRequestBuilder.execute(self)
#      45 def execute(self) -> APIResponse[_ReturnT]:
#      46     """Execute the query.
#      47
#      48     .. tip::
#    (...)
#      55         :class:`APIError` If the API raised an error.
#      56     """
# ---> 57     r = self.session.request(
#      58         self.http_method,
#      59         self.path,
#      60         json=self.json,
#      61         params=self.params,
#      62         headers=self.headers,
#      63     )
#      64     try:
#      65         if (
#      66             200 <= r.status_code <= 299
#      67         ):  # Response.ok from JS (https://developer.mozilla.org/en-US/docs/Web/API/Response/ok)
#
#     [... skipping similar frames: Client._send_handling_auth at line 929 (30 times), Client._send_handling_redirects at line 966 (30 times), Client.request at line 814 (30 times), Client.send at line 901 (30 times), Logger._log at line 1624 (29 times), Client._send_single_request at line 1013 (29 times), Logger.callHandlers at line 1696 (29 times), SupabaseHandler.emit at line 26 (29 times), SyncQueryRequestBuilder.execute at line 57 (29 times), Logger.handle at line 1634 (29 times), Handler.handle at line 968 (29 times), Logger.info at line 1477 (29 times)]
#
# File ~/.local/lib/python3.10/site-packages/httpx/_client.py:1013, in Client._send_single_request(self, request)
#    1010 self.cookies.extract_cookies(response)
#    1011 response.default_encoding = self._default_encoding
# -> 1013 logger.info(
#    1014     'HTTP Request: %s %s "%s %d %s"',
#    1015     request.method,
#    1016     request.url,
#    1017     response.http_version,
#    1018     response.status_code,
#    1019     response.reason_phrase,
#    1020 )
#    1022 return response
#
# File /usr/lib/python3.10/logging/__init__.py:1477, in Logger.info(self, msg, *args, **kwargs)
#    1468 """
#    1469 Log 'msg % args' with severity 'INFO'.
#    1470
#    (...)
#    1474 logger.info("Houston, we have a %s", "interesting problem", exc_info=1)
#    1475 """
#    1476 if self.isEnabledFor(INFO):
# -> 1477     self._log(INFO, msg, args, **kwargs)
#
# File /usr/lib/python3.10/logging/__init__.py:1624, in Logger._log(self, level, msg, args, exc_info, extra, stack_info, stacklevel)
#    1621         exc_info = sys.exc_info()
#    1622 record = self.makeRecord(self.name, level, fn, lno, msg, args,
#    1623                          exc_info, func, extra, sinfo)
# -> 1624 self.handle(record)
#
# File /usr/lib/python3.10/logging/__init__.py:1634, in Logger.handle(self, record)
#    1627 """
#    1628 Call the handlers for the specified record.
#    1629
#    1630 This method is used for unpickled records received from a socket, as
#    1631 well as those created locally. Logger-level filtering is applied.
#    1632 """
#    1633 if (not self.disabled) and self.filter(record):
# -> 1634     self.callHandlers(record)
#
# File /usr/lib/python3.10/logging/__init__.py:1696, in Logger.callHandlers(self, record)
#    1694     found = found + 1
#    1695     if record.levelno >= hdlr.level:
# -> 1696         hdlr.handle(record)
#    1697 if not c.propagate:
#    1698     c = None    #break out
#
# File /usr/lib/python3.10/logging/__init__.py:968, in Handler.handle(self, record)
#     966 self.acquire()
#     967 try:
# --> 968     self.emit(record)
#     969 finally:
#     970     self.release()
#
# Cell In[5], line 26, in SupabaseHandler.emit(self, record)
#      19 try:
#      20     # Insert log entry into Supabase
#      21     data = {
#      22         "level": record.levelname,
#      23         "message": log_entry,
#      24         "file_name": record.pathname  # Add more fields if needed
#      25     }
# ---> 26     supabase.table("logs").insert(data).execute()
#      27     print(data)
#      28     print(log_entry)
#
# File ~/.local/lib/python3.10/site-packages/postgrest/_sync/request_builder.py:57, in SyncQueryRequestBuilder.execute(self)
#      45 def execute(self) -> APIResponse[_ReturnT]:
#      46     """Execute the query.
#      47
#      48     .. tip::
#    (...)
#      55         :class:`APIError` If the API raised an error.
#      56     """
# ---> 57     r = self.session.request(
#      58         self.http_method,
#      59         self.path,
#      60         json=self.json,
#      61         params=self.params,
#      62         headers=self.headers,
#      63     )
#      64     try:
#      65         if (
#      66             200 <= r.status_code <= 299
#      67         ):  # Response.ok from JS (https://developer.mozilla.org/en-US/docs/Web/API/Response/ok)
#
# File ~/.local/lib/python3.10/site-packages/httpx/_client.py:814, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     799     warnings.warn(message, DeprecationWarning)
#     801 request = self.build_request(
#     802     method=method,
#     803     url=url,
#    (...)
#     812     extensions=extensions,
#     813 )
# --> 814 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~/.local/lib/python3.10/site-packages/httpx/_client.py:901, in Client.send(self, request, stream, auth, follow_redirects)
#     893 follow_redirects = (
#     894     self.follow_redirects
#     895     if isinstance(follow_redirects, UseClientDefault)
#     896     else follow_redirects
#     897 )
#     899 auth = self._build_request_auth(request, auth)
# --> 901 response = self._send_handling_auth(
#     902     request,
#     903     auth=auth,
#     904     follow_redirects=follow_redirects,
#     905     history=[],
#     906 )
#     907 try:
#     908     if not stream:
#
# File ~/.local/lib/python3.10/site-packages/httpx/_client.py:929, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     926 request = next(auth_flow)
#     928 while True:
# --> 929     response = self._send_handling_redirects(
#     930         request,
#     931         follow_redirects=follow_redirects,
#     932         history=history,
#     933     )
#     934     try:
#     935         try:
#
# File ~/.local/lib/python3.10/site-packages/httpx/_client.py:966, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     963 for hook in self._event_hooks["request"]:
#     964     hook(request)
# --> 966 response = self._send_single_request(request)
#     967 try:
#     968     for hook in self._event_hooks["response"]:
#
# File ~/.local/lib/python3.10/site-packages/httpx/_client.py:1002, in Client._send_single_request(self, request)
#     997     raise RuntimeError(
#     998         "Attempted to send an async request with a sync Client instance."
#     999     )
#    1001 with request_context(request=request):
# -> 1002     response = transport.handle_request(request)
#    1004 assert isinstance(response.stream, SyncByteStream)
#    1006 response.request = request
#
# File ~/.local/lib/python3.10/site-packages/httpx/_transports/default.py:228, in HTTPTransport.handle_request(self, request)
#     215 req = httpcore.Request(
#     216     method=request.method,
#     217     url=httpcore.URL(
#    (...)
#     225     extensions=request.extensions,
#     226 )
#     227 with map_httpcore_exceptions():
# --> 228     resp = self._pool.handle_request(req)
#     230 assert isinstance(resp.stream, typing.Iterable)
#     232 return Response(
#     233     status_code=resp.status,
#     234     headers=resp.headers,
#     235     stream=ResponseStream(resp.stream),
#     236     extensions=resp.extensions,
#     237 )
#
# File ~/.local/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:268, in ConnectionPool.handle_request(self, request)
#     266     with ShieldCancellation():
#     267         self.response_closed(status)
# --> 268     raise exc
#     269 else:
#     270     break
#
# File ~/.local/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:251, in ConnectionPool.handle_request(self, request)
#     248         raise exc
#     250 try:
# --> 251     response = connection.handle_request(request)
#     252 except ConnectionNotAvailable:
#     253     # The ConnectionNotAvailable exception is a special case, that
#     254     # indicates we need to retry the request on a new connection.
#    (...)
#     258     # might end up as an HTTP/2 connection, but which actually ends
#     259     # up as HTTP/1.1.
#     260     with self._pool_lock:
#     261         # Maintain our position in the request queue, but reset the
#     262         # status so that the request becomes queued again.
#
# File ~/.local/lib/python3.10/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     elif not self._connection.is_available():
#     101         raise ConnectionNotAvailable()
# --> 103 return self._connection.handle_request(request)
#
# File ~/.local/lib/python3.10/site-packages/httpcore/_sync/http11.py:133, in HTTP11Connection.handle_request(self, request)
#     131     with Trace("response_closed", logger, request) as trace:
#     132         self._response_closed()
# --> 133 raise exc
#
# File ~/.local/lib/python3.10/site-packages/httpcore/_sync/http11.py:111, in HTTP11Connection.handle_request(self, request)
#     101     pass
#     103 with Trace(
#     104     "receive_response_headers", logger, request, kwargs
#     105 ) as trace:
#     106     (
#     107         http_version,
#     108         status,
#     109         reason_phrase,
#     110         headers,
# --> 111     ) = self._receive_response_headers(**kwargs)
#     112     trace.return_value = (
#     113         http_version,
#     114         status,
#     115         reason_phrase,
#     116         headers,
#     117     )
#     119 return Response(
#     120     status=status,
#     121     headers=headers,
#    (...)
#     127     },
#     128 )
#
# File ~/.local/lib/python3.10/site-packages/httpcore/_sync/http11.py:176, in HTTP11Connection._receive_response_headers(self, request)
#     173 timeout = timeouts.get("read", None)
#     175 while True:
# --> 176     event = self._receive_event(timeout=timeout)
#     177     if isinstance(event, h11.Response):
#     178         break
#
# File ~/.local/lib/python3.10/site-packages/httpcore/_sync/http11.py:212, in HTTP11Connection._receive_event(self, timeout)
#     209     event = self._h11_state.next_event()
#     211 if event is h11.NEED_DATA:
# --> 212     data = self._network_stream.read(
#     213         self.READ_NUM_BYTES, timeout=timeout
#     214     )
#     216     # If we feed this case through h11 we'll raise an exception like:
#     217     #
#     218     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     222     # perspective. Instead we handle this case distinctly and treat
#     223     # it as a ConnectError.
#     224     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/.local/lib/python3.10/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# File /usr/lib/python3.10/ssl.py:1288, in SSLSocket.recv(self, buflen, flags)
#    1284     if flags != 0:
#    1285         raise ValueError(
#    1286             "non-zero flags not allowed in calls to recv() on %s" %
#    1287             self.__class__)
# -> 1288     return self.read(buflen)
#    1289 else:
#    1290     return super().recv(buflen, flags)
#
# File /usr/lib/python3.10/ssl.py:1161, in SSLSocket.read(self, len, buffer)
#    1159         return self._sslobj.read(len, buffer)
#    1160     else:
# -> 1161         return self._sslobj.read(len)
#    1162 except SSLError as x:
#    1163     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:
# 2024-08-16 22:18:25,972:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:26,141:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:26,292:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:26,448:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:26,609:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:26,752:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:26,909:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:27,063:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:27,217:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:27,365:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:27,518:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:27,670:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:27,827:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:27,993:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:28,146:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:28,295:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:28,447:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:28,595:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:28,749:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:28,893:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:29,042:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:29,189:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:29,349:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:29,500:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:29,662:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:29,848:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:29,998:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:30,152:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:30,314:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:30,465:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:30,613:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:30,760:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:30,923:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:31,074:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:31,238:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:31,389:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:31,554:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:31,722:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:31,887:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:32,051:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:32,210:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:32,361:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:32,532:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:32,696:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:32,857:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:33,012:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:33,215:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:33,437:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:33,635:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:33,846:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:34,052:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:34,242:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:34,498:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:34,804:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:35,107:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:35,519:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:35,926:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:36,336:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:36,746:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:37,161:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:37,568:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:37,977:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:38,388:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:38,797:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:39,206:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:39,617:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:39,778:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:18:39,936:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# Failed to log to Supabase:
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826919.7782776
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826919.617122
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826919.206927
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826918.797037
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826918.3883538
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826917.977754
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826917.5680115
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826917.1619196
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826916.7468786
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826916.3363903
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826915.926705
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826915.5191283
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826915.1078968
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826914.8049817
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826914.4981813
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826914.2423458
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826914.0521867
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826913.8462217
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826913.6357703
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826913.4377937
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826913.2159815
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826913.0128338
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826912.8570745
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826912.6960535
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826912.5324657
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826912.361222
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826912.210329
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826912.051018
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826911.887124
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826911.7226882
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826911.554939
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826911.3895547
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826911.2380989
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826911.074232
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826910.9236996
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826910.7605126
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826910.6133597
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826910.4657333
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826910.3145454
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826910.1521385
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826909.9987357
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826909.8486903
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826909.662334
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826909.5004935
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826909.3493137
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826909.1898658
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826909.042507
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826908.8931665
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826908.7491038
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826908.5952578
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826908.4474778
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826908.2957182
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826908.1465812
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826907.9936666
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826907.8273737
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826907.6701984
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826907.5185554
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826907.3654802
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826907.2170494
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826907.0638375
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826906.9092298
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826906.752514
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826906.6092932
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826906.448338
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826906.2921562
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826906.141442
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826905.9726412
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826905.7860548
# {'level': 'INFO', 'message': 'HTTP Request: GET https://api.gradio.app/pkg-version "HTTP/1.1 200 OK"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: GET https://api.gradio.app/pkg-version "HTTP/1.1 200 OK"
# 1723826901.338035

# %%
pip install supabase
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: supabase in /home/abinaya/.local/lib/python3.10/site-packages (2.3.1)
# Requirement already satisfied: httpx<0.26,>=0.24 in /home/abinaya/.local/lib/python3.10/site-packages (from supabase) (0.25.2)
# Requirement already satisfied: supafunc<0.4.0,>=0.3.1 in /home/abinaya/.local/lib/python3.10/site-packages (from supabase) (0.3.3)
# Requirement already satisfied: postgrest<0.14.0,>=0.10.8 in /home/abinaya/.local/lib/python3.10/site-packages (from supabase) (0.13.1)
# Requirement already satisfied: storage3<0.8.0,>=0.5.3 in /home/abinaya/.local/lib/python3.10/site-packages (from supabase) (0.7.0)
# Requirement already satisfied: gotrue<3.0,>=1.3 in /home/abinaya/.local/lib/python3.10/site-packages (from supabase) (2.1.0)
# Requirement already satisfied: realtime<2.0.0,>=1.0.0 in /home/abinaya/.local/lib/python3.10/site-packages (from supabase) (1.0.0)
# Requirement already satisfied: pydantic<3,>=1.10 in /home/abinaya/.local/lib/python3.10/site-packages (from gotrue<3.0,>=1.3->supabase) (2.8.2)
# Requirement already satisfied: sniffio in /home/abinaya/.local/lib/python3.10/site-packages (from httpx<0.26,>=0.24->supabase) (1.3.0)
# Requirement already satisfied: anyio in /home/abinaya/.local/lib/python3.10/site-packages (from httpx<0.26,>=0.24->supabase) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /home/abinaya/.local/lib/python3.10/site-packages (from httpx<0.26,>=0.24->supabase) (1.0.2)
# Requirement already satisfied: certifi in /usr/lib/python3/dist-packages (from httpx<0.26,>=0.24->supabase) (2020.6.20)
# Requirement already satisfied: idna in /usr/lib/python3/dist-packages (from httpx<0.26,>=0.24->supabase) (3.3)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/abinaya/.local/lib/python3.10/site-packages (from httpcore==1.*->httpx<0.26,>=0.24->supabase) (0.14.0)
# Requirement already satisfied: strenum<0.5.0,>=0.4.9 in /home/abinaya/.local/lib/python3.10/site-packages (from postgrest<0.14.0,>=0.10.8->supabase) (0.4.10)
# Requirement already satisfied: deprecation<3.0.0,>=2.1.0 in /home/abinaya/.local/lib/python3.10/site-packages (from postgrest<0.14.0,>=0.10.8->supabase) (2.1.0)
# Requirement already satisfied: websockets<11.0,>=10.3 in /home/abinaya/.local/lib/python3.10/site-packages (from realtime<2.0.0,>=1.0.0->supabase) (10.4)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.1 in /home/abinaya/.local/lib/python3.10/site-packages (from realtime<2.0.0,>=1.0.0->supabase) (2.8.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.2.0 in /home/abinaya/.local/lib/python3.10/site-packages (from realtime<2.0.0,>=1.0.0->supabase) (4.8.0)
# Requirement already satisfied: packaging in /home/abinaya/.local/lib/python3.10/site-packages (from deprecation<3.0.0,>=2.1.0->postgrest<0.14.0,>=0.10.8->supabase) (23.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /home/abinaya/.local/lib/python3.10/site-packages (from pydantic<3,>=1.10->gotrue<3.0,>=1.3->supabase) (2.20.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/abinaya/.local/lib/python3.10/site-packages (from pydantic<3,>=1.10->gotrue<3.0,>=1.3->supabase) (0.7.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil<3.0.0,>=2.8.1->realtime<2.0.0,>=1.0.0->supabase) (1.16.0)
# Requirement already satisfied: exceptiongroup in /home/abinaya/.local/lib/python3.10/site-packages (from anyio->httpx<0.26,>=0.24->supabase) (1.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import gradio as gr
from pdf2image import convert_from_path
import pytesseract
import pandas as pd
import re
import os
import logging
from supabase import create_client, Client

# Initialize Supabase client
url = "https://qumfinzjetrdhzmbuwcz.supabase.co" #"your_supabase_url"
key = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6InF1bWZpbnpqZXRyZGh6bWJ1d2N6Iiwicm9sZSI6ImFub24iLCJpYXQiOjE3MjM3ODU2NTUsImV4cCI6MjAzOTM2MTY1NX0.e8SwMVAOEILIgWk4QaJu0STayCur7uyJEnMXBNUxadg" #"your_supabase_key"
supabase: Client = create_client(url, key)

# Define the Supabase logging handler
class SupabaseHandler(logging.Handler):
    def emit(self, record):
        log_entry = self.format(record)
        try:
            # Insert log entry into Supabase
            data = {
                "level": record.levelname,
                "message": log_entry,
                "file_name": record.pathname  # Add more fields if needed
            }
            result=supabase.table("logs").insert(data).execute()

        # Check if the insertion was successful
            if hasattr(result, 'data') and len(result.data) > 0:
                print(f"Log entry successfully added to Supabase: {result.data[0]['id']}")
            else:
                print(f"Failed to add log entry to Supabase: {result}")
        except Exception as e:
            # Use sys.stderr.write() for error output
            import sys
            sys.stderr.write(f"Failed to log to Supabase: {str(e)}\n")

# Configure logging to use both file and Supabase
supabase_handler = SupabaseHandler()
logging.basicConfig(
    level=logging.DEBUG, 
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler('process_log.log'),
        supabase_handler
    ]
)

# # Explicitly add the SupabaseHandler to the root logger
# logger = logging.getLogger()  # Root logger
# logger.addHandler(supabase_handler)

def process_pdf(file):
    try:
        logging.info(f"Processing file: {file.name}")

        # Check if the file is a PDF
        if not file.name.lower().endswith('.pdf'):
            logging.warning("Uploaded file is not a PDF.")
            return "Error: Uploaded file is not a PDF. Please upload a PDF file.", None
        
        # Convert PDF to images
        images = convert_from_path(file.name)
        logging.info(f"PDF converted to {len(images)} image(s).")

        full_text = ""
        for i, img in enumerate(images):
            text = pytesseract.image_to_string(img)
            logging.debug(f"Text extracted from image {i+1}: {text[:100]}...")
            full_text += text + "\n"
        
        # If no text was extracted, likely a wrong or empty PDF
        if not full_text.strip():
            logging.error("No text could be extracted from the PDF.")
            return "Error: Unable to extract text. The PDF might be blank or incorrectly formatted.", None

        # Check for required keywords
        required_keywords = ['invoice', 'order no', 'invoice date', 'supplier name', 'warehouse id']
        if not any(keyword in full_text.lower() for keyword in required_keywords):
            logging.warning("Necessary keywords not found in the PDF.")
            return "Error: The uploaded PDF does not contain necessary fields like 'Invoice', 'Order No', etc. Please upload a correct invoice.", None
        
        # Save extracted data to CSV
        csv_data = save_to_csv(full_text)
        csv_path = "output.csv"  # Specify the output CSV file name
        with open(csv_path, "w") as f:
            f.write(csv_data)  # Write the CSV data to the file

        logging.info("Processing completed successfully.")
        return "Processing Complete", csv_path  # Return the file path

    except Exception as e:
        logging.error(f"An unexpected error occurred: {str(e)}")
        return f"Error: An unexpected error occurred: {str(e)}", None

def extract_fields(text):
    logging.debug("Extracting fields from text.")
    invoice_no = re.search(r'Invoice No:\s*([A-Z0-9-]+)', text)
    order_no = re.search(r'HM Order No:\s*(\d+)', text)
    invoice_date = re.search(r'Invoice Date:\s*([\d-]+)', text)
    supplier_name = re.search(r'Supplier Name:\s*([A-Z\s]+)', text)
    warehouse_id = re.search(r'\bINW\d{3}\b', text)
    
    description_of_goods = None
    if warehouse_id:
        warehouse_line_start = text.find(warehouse_id.group(0))
        description_lines = []
        lines = text[warehouse_line_start:].split('\n')
        for line in lines:
            if "Container No:" in line:
                break
            description_lines.append(line.strip())
        description = ' '.join(description_lines).replace(' Cartons', '')
        words = description.split()
        # Filter out the warehouse ID explicitly from the description
        filtered_words = [
            word for word in words
            if not re.match(r'^\d+(\.\d+)?$', word) and word.lower() not in ['usd', 'pieces'] and '=' not in word and word != warehouse_id.group(0)
        ]

        description_of_goods = ' '.join(filtered_words)

    logging.debug(f"Fields extracted: Invoice No: {invoice_no}, Order No: {order_no}, Invoice Date: {invoice_date}, Supplier Name: {supplier_name}, Warehouse ID: {warehouse_id}")
    return {
        'Invoice No': invoice_no.group(1) if invoice_no else None,
        'HM Order No': order_no.group(1) if order_no else None,
        'Invoice Date': invoice_date.group(1) if invoice_date else None,
        'Supplier Name': supplier_name.group(1).strip() if supplier_name else None,
        'Warehouse ID': warehouse_id.group(0) if warehouse_id else None,
        'Description of Goods': description_of_goods
    }

def save_to_csv(full_text):
    logging.info("Saving extracted fields to CSV.")
    invoice_texts = full_text.split('INVOICE')
    data = []

    for i in range(1, len(invoice_texts)):
        invoice_text = "INVOICE" + invoice_texts[i]
        fields = extract_fields(invoice_text)
        if fields['Invoice No']:
            data.append(fields)
    
    df_invoices = pd.DataFrame(data)
    
    # Function to fix hanging words and capitalize text
    def fix_description(description):
        words = description.split()
        fixed_words = []
        for i in range(len(words) - 1):
            if len(words[i + 1]) <= 2:
                fixed_words.append(words[i] + words[i + 1])
            else:
                if len(words[i]) > 2:
                    fixed_words.append(words[i])
        if len(words[-1]) > 1:
            fixed_words.append(words[-1])

        return " ".join(fixed_words).upper()

    df_invoices['Description of Goods'] = df_invoices['Description of Goods'].apply(fix_description)

    csv_data = df_invoices.to_csv(index=False)
    logging.info("CSV file created successfully.")
    return csv_data

iface = gr.Interface(
    fn=process_pdf,
    inputs=gr.File(file_types=['.pdf']),
    outputs=[gr.Textbox(), gr.File(label="Download CSV")]
)

iface.launch()
# Out:
# 2024-08-16 22:11:41,144:INFO - HTTP Request: GET http://127.0.0.1:7864/startup-events "HTTP/1.1 200 OK"
# Running on local URL:  http://127.0.0.1:7864
# 2024-08-16 22:11:41,574:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:41,822:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:41,977:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:42,089:INFO - HTTP Request: GET https://api.gradio.app/pkg-version "HTTP/1.1 200 OK"
# 2024-08-16 22:11:42,140:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:42,337:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:42,498:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:42,653:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:42,871:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:43,034:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:43,202:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:43,385:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:43,620:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:43,777:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:43,936:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:44,104:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:44,260:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:44,418:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:44,600:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:44,761:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:44,921:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:45,077:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:45,245:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:45,409:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:45,571:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:45,738:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:45,893:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:46,062:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:46,246:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:46,412:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:46,655:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:46,900:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 173
#     165     return csv_data
#     167 iface = gr.Interface(
#     168     fn=process_pdf,
#     169     inputs=gr.File(file_types=['.pdf']),
#     170     outputs=[gr.Textbox(), gr.File(label="Download CSV")]
#     171 )
# --> 173 iface.launch()
#
# File ~/.local/lib/python3.10/site-packages/gradio/blocks.py:2399, in Blocks.launch(self, inline, inbrowser, share, debug, max_threads, auth, auth_message, prevent_thread_lock, show_error, server_name, server_port, height, width, favicon_path, ssl_keyfile, ssl_certfile, ssl_keyfile_password, ssl_verify, quiet, show_api, allowed_paths, blocked_paths, root_path, app_kwargs, state_session_capacity, share_server_address, share_server_protocol, auth_dependency, max_file_size, _frontend, enable_monitoring)
#    2394 self._queue.set_server_app(self.server_app)
#    2396 if not wasm_utils.IS_WASM:
#    2397     # Cannot run async functions in background other than app's scope.
#    2398     # Workaround by triggering the app endpoint
# -> 2399     httpx.get(
#    2400         f"{self.local_url}startup-events", verify=ssl_verify, timeout=None
#    2401     )
#    2402 else:
#    2403     # NOTE: One benefit of the code above dispatching `startup_events()` via a self HTTP request is
#    2404     # that `self._queue.start()` is called in another thread which is managed by the HTTP server, `uvicorn`
#    (...)
#    2407     # In contrast, in the Wasm env, we can't do that because `threading` is not supported and all async tasks will run in the same event loop, `pyodide.webloop.WebLoop` in the main thread.
#    2408     # So we need to manually cancel them. See `self.close()`..
#    2409     self.startup_events()
#
# File ~/.local/lib/python3.10/site-packages/httpx/_api.py:189, in get(url, params, headers, cookies, auth, proxies, follow_redirects, cert, verify, timeout, trust_env)
#     167 def get(
#     168     url: URLTypes,
#     169     *,
#    (...)
#     179     trust_env: bool = True,
#     180 ) -> Response:
#     181     """
#     182     Sends a `GET` request.
#     183
#    (...)
#     187     on this function, as `GET` requests should not include a request body.
#     188     """
# --> 189     return request(
#     190         "GET",
#     191         url,
#     192         params=params,
#     193         headers=headers,
#     194         cookies=cookies,
#     195         auth=auth,
#     196         proxies=proxies,
#     197         follow_redirects=follow_redirects,
#     198         cert=cert,
#     199         verify=verify,
#     200         timeout=timeout,
#     201         trust_env=trust_env,
#     202     )
#
# File ~/.local/lib/python3.10/site-packages/httpx/_api.py:100, in request(method, url, params, content, data, files, json, headers, cookies, auth, proxies, timeout, follow_redirects, verify, cert, trust_env)
#      42 """
#      43 Sends an HTTP request.
#      44
#    (...)
#      90 ```
#      91 """
#      92 with Client(
#      93     cookies=cookies,
#      94     proxies=proxies,
#    (...)
#      98     trust_env=trust_env,
#      99 ) as client:
# --> 100     return client.request(
#     101         method=method,
#     102         url=url,
#     103         content=content,
#     104         data=data,
#     105         files=files,
#     106         json=json,
#     107         params=params,
#     108         headers=headers,
#     109         auth=auth,
#     110         follow_redirects=follow_redirects,
#     111     )
#
# File ~/.local/lib/python3.10/site-packages/httpx/_client.py:814, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     799     warnings.warn(message, DeprecationWarning)
#     801 request = self.build_request(
#     802     method=method,
#     803     url=url,
#    (...)
#     812     extensions=extensions,
#     813 )
# --> 814 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~/.local/lib/python3.10/site-packages/httpx/_client.py:901, in Client.send(self, request, stream, auth, follow_redirects)
#     893 follow_redirects = (
#     894     self.follow_redirects
#     895     if isinstance(follow_redirects, UseClientDefault)
#     896     else follow_redirects
#     897 )
#     899 auth = self._build_request_auth(request, auth)
# --> 901 response = self._send_handling_auth(
#     902     request,
#     903     auth=auth,
#     904     follow_redirects=follow_redirects,
#     905     history=[],
#     906 )
#     907 try:
#     908     if not stream:
#
# File ~/.local/lib/python3.10/site-packages/httpx/_client.py:929, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     926 request = next(auth_flow)
#     928 while True:
# --> 929     response = self._send_handling_redirects(
#     930         request,
#     931         follow_redirects=follow_redirects,
#     932         history=history,
#     933     )
#     934     try:
#     935         try:
#
# File ~/.local/lib/python3.10/site-packages/httpx/_client.py:966, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     963 for hook in self._event_hooks["request"]:
#     964     hook(request)
# --> 966 response = self._send_single_request(request)
#     967 try:
#     968     for hook in self._event_hooks["response"]:
#
# File ~/.local/lib/python3.10/site-packages/httpx/_client.py:1013, in Client._send_single_request(self, request)
#    1010 self.cookies.extract_cookies(response)
#    1011 response.default_encoding = self._default_encoding
# -> 1013 logger.info(
#    1014     'HTTP Request: %s %s "%s %d %s"',
#    1015     request.method,
#    1016     request.url,
#    1017     response.http_version,
#    1018     response.status_code,
#    1019     response.reason_phrase,
#    1020 )
#    1022 return response
#
# File /usr/lib/python3.10/logging/__init__.py:1477, in Logger.info(self, msg, *args, **kwargs)
#    1468 """
#    1469 Log 'msg % args' with severity 'INFO'.
#    1470
#    (...)
#    1474 logger.info("Houston, we have a %s", "interesting problem", exc_info=1)
#    1475 """
#    1476 if self.isEnabledFor(INFO):
# -> 1477     self._log(INFO, msg, args, **kwargs)
#
# File /usr/lib/python3.10/logging/__init__.py:1624, in Logger._log(self, level, msg, args, exc_info, extra, stack_info, stacklevel)
#    1621         exc_info = sys.exc_info()
#    1622 record = self.makeRecord(self.name, level, fn, lno, msg, args,
#    1623                          exc_info, func, extra, sinfo)
# -> 1624 self.handle(record)
#
# File /usr/lib/python3.10/logging/__init__.py:1634, in Logger.handle(self, record)
#    1627 """
#    1628 Call the handlers for the specified record.
#    1629
#    1630 This method is used for unpickled records received from a socket, as
#    1631 well as those created locally. Logger-level filtering is applied.
#    1632 """
#    1633 if (not self.disabled) and self.filter(record):
# -> 1634     self.callHandlers(record)
#
# File /usr/lib/python3.10/logging/__init__.py:1696, in Logger.callHandlers(self, record)
#    1694     found = found + 1
#    1695     if record.levelno >= hdlr.level:
# -> 1696         hdlr.handle(record)
#    1697 if not c.propagate:
#    1698     c = None    #break out
#
# File /usr/lib/python3.10/logging/__init__.py:968, in Handler.handle(self, record)
#     966 self.acquire()
#     967 try:
# --> 968     self.emit(record)
#     969 finally:
#     970     self.release()
#
# Cell In[5], line 26, in SupabaseHandler.emit(self, record)
#      19 try:
#      20     # Insert log entry into Supabase
#      21     data = {
#      22         "level": record.levelname,
#      23         "message": log_entry,
#      24         "file_name": record.pathname  # Add more fields if needed
#      25     }
# ---> 26     supabase.table("logs").insert(data).execute()
#      27     print(data)
#      28     print(log_entry)
#
# File ~/.local/lib/python3.10/site-packages/postgrest/_sync/request_builder.py:57, in SyncQueryRequestBuilder.execute(self)
#      45 def execute(self) -> APIResponse[_ReturnT]:
#      46     """Execute the query.
#      47
#      48     .. tip::
#    (...)
#      55         :class:`APIError` If the API raised an error.
#      56     """
# ---> 57     r = self.session.request(
#      58         self.http_method,
#      59         self.path,
#      60         json=self.json,
#      61         params=self.params,
#      62         headers=self.headers,
#      63     )
#      64     try:
#      65         if (
#      66             200 <= r.status_code <= 299
#      67         ):  # Response.ok from JS (https://developer.mozilla.org/en-US/docs/Web/API/Response/ok)
#
# File ~/.local/lib/python3.10/site-packages/httpx/_client.py:814, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     799     warnings.warn(message, DeprecationWarning)
#     801 request = self.build_request(
#     802     method=method,
#     803     url=url,
#    (...)
#     812     extensions=extensions,
#     813 )
# --> 814 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~/.local/lib/python3.10/site-packages/httpx/_client.py:901, in Client.send(self, request, stream, auth, follow_redirects)
#     893 follow_redirects = (
#     894     self.follow_redirects
#     895     if isinstance(follow_redirects, UseClientDefault)
#     896     else follow_redirects
#     897 )
#     899 auth = self._build_request_auth(request, auth)
# --> 901 response = self._send_handling_auth(
#     902     request,
#     903     auth=auth,
#     904     follow_redirects=follow_redirects,
#     905     history=[],
#     906 )
#     907 try:
#     908     if not stream:
#
# File ~/.local/lib/python3.10/site-packages/httpx/_client.py:929, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     926 request = next(auth_flow)
#     928 while True:
# --> 929     response = self._send_handling_redirects(
#     930         request,
#     931         follow_redirects=follow_redirects,
#     932         history=history,
#     933     )
#     934     try:
#     935         try:
#
# File ~/.local/lib/python3.10/site-packages/httpx/_client.py:966, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     963 for hook in self._event_hooks["request"]:
#     964     hook(request)
# --> 966 response = self._send_single_request(request)
#     967 try:
#     968     for hook in self._event_hooks["response"]:
#
# File ~/.local/lib/python3.10/site-packages/httpx/_client.py:1013, in Client._send_single_request(self, request)
#    1010 self.cookies.extract_cookies(response)
#    1011 response.default_encoding = self._default_encoding
# -> 1013 logger.info(
#    1014     'HTTP Request: %s %s "%s %d %s"',
#    1015     request.method,
#    1016     request.url,
#    1017     response.http_version,
#    1018     response.status_code,
#    1019     response.reason_phrase,
#    1020 )
#    1022 return response
#
# File /usr/lib/python3.10/logging/__init__.py:1477, in Logger.info(self, msg, *args, **kwargs)
#    1468 """
#    1469 Log 'msg % args' with severity 'INFO'.
#    1470
#    (...)
#    1474 logger.info("Houston, we have a %s", "interesting problem", exc_info=1)
#    1475 """
#    1476 if self.isEnabledFor(INFO):
# -> 1477     self._log(INFO, msg, args, **kwargs)
#
# File /usr/lib/python3.10/logging/__init__.py:1624, in Logger._log(self, level, msg, args, exc_info, extra, stack_info, stacklevel)
#    1621         exc_info = sys.exc_info()
#    1622 record = self.makeRecord(self.name, level, fn, lno, msg, args,
#    1623                          exc_info, func, extra, sinfo)
# -> 1624 self.handle(record)
#
# File /usr/lib/python3.10/logging/__init__.py:1634, in Logger.handle(self, record)
#    1627 """
#    1628 Call the handlers for the specified record.
#    1629
#    1630 This method is used for unpickled records received from a socket, as
#    1631 well as those created locally. Logger-level filtering is applied.
#    1632 """
#    1633 if (not self.disabled) and self.filter(record):
# -> 1634     self.callHandlers(record)
#
# File /usr/lib/python3.10/logging/__init__.py:1696, in Logger.callHandlers(self, record)
#    1694     found = found + 1
#    1695     if record.levelno >= hdlr.level:
# -> 1696         hdlr.handle(record)
#    1697 if not c.propagate:
#    1698     c = None    #break out
#
# File /usr/lib/python3.10/logging/__init__.py:968, in Handler.handle(self, record)
#     966 self.acquire()
#     967 try:
# --> 968     self.emit(record)
#     969 finally:
#     970     self.release()
#
# Cell In[5], line 26, in SupabaseHandler.emit(self, record)
#      19 try:
#      20     # Insert log entry into Supabase
#      21     data = {
#      22         "level": record.levelname,
#      23         "message": log_entry,
#      24         "file_name": record.pathname  # Add more fields if needed
#      25     }
# ---> 26     supabase.table("logs").insert(data).execute()
#      27     print(data)
#      28     print(log_entry)
#
# File ~/.local/lib/python3.10/site-packages/postgrest/_sync/request_builder.py:57, in SyncQueryRequestBuilder.execute(self)
#      45 def execute(self) -> APIResponse[_ReturnT]:
#      46     """Execute the query.
#      47
#      48     .. tip::
#    (...)
#      55         :class:`APIError` If the API raised an error.
#      56     """
# ---> 57     r = self.session.request(
#      58         self.http_method,
#      59         self.path,
#      60         json=self.json,
#      61         params=self.params,
#      62         headers=self.headers,
#      63     )
#      64     try:
#      65         if (
#      66             200 <= r.status_code <= 299
#      67         ):  # Response.ok from JS (https://developer.mozilla.org/en-US/docs/Web/API/Response/ok)
#
#     [... skipping similar frames: Client._send_handling_auth at line 929 (28 times), Client._send_handling_redirects at line 966 (28 times), Client.request at line 814 (28 times), Client.send at line 901 (28 times), Logger._log at line 1624 (27 times), Client._send_single_request at line 1013 (27 times), Logger.callHandlers at line 1696 (27 times), SupabaseHandler.emit at line 26 (27 times), SyncQueryRequestBuilder.execute at line 57 (27 times), Logger.handle at line 1634 (27 times), Handler.handle at line 968 (27 times), Logger.info at line 1477 (27 times)]
#
# File ~/.local/lib/python3.10/site-packages/httpx/_client.py:1013, in Client._send_single_request(self, request)
#    1010 self.cookies.extract_cookies(response)
#    1011 response.default_encoding = self._default_encoding
# -> 1013 logger.info(
#    1014     'HTTP Request: %s %s "%s %d %s"',
#    1015     request.method,
#    1016     request.url,
#    1017     response.http_version,
#    1018     response.status_code,
#    1019     response.reason_phrase,
#    1020 )
#    1022 return response
#
# File /usr/lib/python3.10/logging/__init__.py:1477, in Logger.info(self, msg, *args, **kwargs)
#    1468 """
#    1469 Log 'msg % args' with severity 'INFO'.
#    1470
#    (...)
#    1474 logger.info("Houston, we have a %s", "interesting problem", exc_info=1)
#    1475 """
#    1476 if self.isEnabledFor(INFO):
# -> 1477     self._log(INFO, msg, args, **kwargs)
#
# File /usr/lib/python3.10/logging/__init__.py:1624, in Logger._log(self, level, msg, args, exc_info, extra, stack_info, stacklevel)
#    1621         exc_info = sys.exc_info()
#    1622 record = self.makeRecord(self.name, level, fn, lno, msg, args,
#    1623                          exc_info, func, extra, sinfo)
# -> 1624 self.handle(record)
#
# File /usr/lib/python3.10/logging/__init__.py:1634, in Logger.handle(self, record)
#    1627 """
#    1628 Call the handlers for the specified record.
#    1629
#    1630 This method is used for unpickled records received from a socket, as
#    1631 well as those created locally. Logger-level filtering is applied.
#    1632 """
#    1633 if (not self.disabled) and self.filter(record):
# -> 1634     self.callHandlers(record)
#
# File /usr/lib/python3.10/logging/__init__.py:1696, in Logger.callHandlers(self, record)
#    1694     found = found + 1
#    1695     if record.levelno >= hdlr.level:
# -> 1696         hdlr.handle(record)
#    1697 if not c.propagate:
#    1698     c = None    #break out
#
# File /usr/lib/python3.10/logging/__init__.py:968, in Handler.handle(self, record)
#     966 self.acquire()
#     967 try:
# --> 968     self.emit(record)
#     969 finally:
#     970     self.release()
#
# Cell In[5], line 26, in SupabaseHandler.emit(self, record)
#      19 try:
#      20     # Insert log entry into Supabase
#      21     data = {
#      22         "level": record.levelname,
#      23         "message": log_entry,
#      24         "file_name": record.pathname  # Add more fields if needed
#      25     }
# ---> 26     supabase.table("logs").insert(data).execute()
#      27     print(data)
#      28     print(log_entry)
#
# File ~/.local/lib/python3.10/site-packages/postgrest/_sync/request_builder.py:57, in SyncQueryRequestBuilder.execute(self)
#      45 def execute(self) -> APIResponse[_ReturnT]:
#      46     """Execute the query.
#      47
#      48     .. tip::
#    (...)
#      55         :class:`APIError` If the API raised an error.
#      56     """
# ---> 57     r = self.session.request(
#      58         self.http_method,
#      59         self.path,
#      60         json=self.json,
#      61         params=self.params,
#      62         headers=self.headers,
#      63     )
#      64     try:
#      65         if (
#      66             200 <= r.status_code <= 299
#      67         ):  # Response.ok from JS (https://developer.mozilla.org/en-US/docs/Web/API/Response/ok)
#
# File ~/.local/lib/python3.10/site-packages/httpx/_client.py:814, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     799     warnings.warn(message, DeprecationWarning)
#     801 request = self.build_request(
#     802     method=method,
#     803     url=url,
#    (...)
#     812     extensions=extensions,
#     813 )
# --> 814 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~/.local/lib/python3.10/site-packages/httpx/_client.py:901, in Client.send(self, request, stream, auth, follow_redirects)
#     893 follow_redirects = (
#     894     self.follow_redirects
#     895     if isinstance(follow_redirects, UseClientDefault)
#     896     else follow_redirects
#     897 )
#     899 auth = self._build_request_auth(request, auth)
# --> 901 response = self._send_handling_auth(
#     902     request,
#     903     auth=auth,
#     904     follow_redirects=follow_redirects,
#     905     history=[],
#     906 )
#     907 try:
#     908     if not stream:
#
# File ~/.local/lib/python3.10/site-packages/httpx/_client.py:929, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     926 request = next(auth_flow)
#     928 while True:
# --> 929     response = self._send_handling_redirects(
#     930         request,
#     931         follow_redirects=follow_redirects,
#     932         history=history,
#     933     )
#     934     try:
#     935         try:
#
# File ~/.local/lib/python3.10/site-packages/httpx/_client.py:966, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     963 for hook in self._event_hooks["request"]:
#     964     hook(request)
# --> 966 response = self._send_single_request(request)
#     967 try:
#     968     for hook in self._event_hooks["response"]:
#
# File ~/.local/lib/python3.10/site-packages/httpx/_client.py:1002, in Client._send_single_request(self, request)
#     997     raise RuntimeError(
#     998         "Attempted to send an async request with a sync Client instance."
#     999     )
#    1001 with request_context(request=request):
# -> 1002     response = transport.handle_request(request)
#    1004 assert isinstance(response.stream, SyncByteStream)
#    1006 response.request = request
#
# File ~/.local/lib/python3.10/site-packages/httpx/_transports/default.py:228, in HTTPTransport.handle_request(self, request)
#     215 req = httpcore.Request(
#     216     method=request.method,
#     217     url=httpcore.URL(
#    (...)
#     225     extensions=request.extensions,
#     226 )
#     227 with map_httpcore_exceptions():
# --> 228     resp = self._pool.handle_request(req)
#     230 assert isinstance(resp.stream, typing.Iterable)
#     232 return Response(
#     233     status_code=resp.status,
#     234     headers=resp.headers,
#     235     stream=ResponseStream(resp.stream),
#     236     extensions=resp.extensions,
#     237 )
#
# File ~/.local/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:268, in ConnectionPool.handle_request(self, request)
#     266     with ShieldCancellation():
#     267         self.response_closed(status)
# --> 268     raise exc
#     269 else:
#     270     break
#
# File ~/.local/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:251, in ConnectionPool.handle_request(self, request)
#     248         raise exc
#     250 try:
# --> 251     response = connection.handle_request(request)
#     252 except ConnectionNotAvailable:
#     253     # The ConnectionNotAvailable exception is a special case, that
#     254     # indicates we need to retry the request on a new connection.
#    (...)
#     258     # might end up as an HTTP/2 connection, but which actually ends
#     259     # up as HTTP/1.1.
#     260     with self._pool_lock:
#     261         # Maintain our position in the request queue, but reset the
#     262         # status so that the request becomes queued again.
#
# File ~/.local/lib/python3.10/site-packages/httpcore/_sync/connection.py:76, in HTTPConnection.handle_request(self, request)
#      74 if self._connection is None:
#      75     try:
# ---> 76         stream = self._connect(request)
#      78         ssl_object = stream.get_extra_info("ssl_object")
#      79         http2_negotiated = (
#      80             ssl_object is not None
#      81             and ssl_object.selected_alpn_protocol() == "h2"
#      82         )
#
# File ~/.local/lib/python3.10/site-packages/httpcore/_sync/connection.py:124, in HTTPConnection._connect(self, request)
#     116     kwargs = {
#     117         "host": self._origin.host.decode("ascii"),
#     118         "port": self._origin.port,
#    (...)
#     121         "socket_options": self._socket_options,
#     122     }
#     123     with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 124         stream = self._network_backend.connect_tcp(**kwargs)
#     125         trace.return_value = stream
#     126 else:
#
# File ~/.local/lib/python3.10/site-packages/httpcore/_backends/sync.py:206, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     200 exc_map: ExceptionMapping = {
#     201     socket.timeout: ConnectTimeout,
#     202     OSError: ConnectError,
#     203 }
#     205 with map_exceptions(exc_map):
# --> 206     sock = socket.create_connection(
#     207         address,
#     208         timeout,
#     209         source_address=source_address,
#     210     )
#     211     for option in socket_options:
#     212         sock.setsockopt(*option)  # pragma: no cover
#
# File /usr/lib/python3.10/socket.py:824, in create_connection(address, timeout, source_address)
#     822 host, port = address
#     823 err = None
# --> 824 for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     825     af, socktype, proto, canonname, sa = res
#     826     sock = None
#
# File /usr/lib/python3.10/socket.py:955, in getaddrinfo(host, port, family, type, proto, flags)
#     952 # We override this function since we want to translate the numeric family
#     953 # and socket type values to enum constants.
#     954 addrlist = []
# --> 955 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     956     af, socktype, proto, canonname, sa = res
#     957     addrlist.append((_intenum_converter(af, AddressFamily),
#     958                      _intenum_converter(socktype, SocketKind),
#     959                      proto, canonname, sa))
#
# KeyboardInterrupt:
# 2024-08-16 22:11:47,061:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:47,218:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:47,371:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:47,528:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:47,679:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:47,857:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:48,025:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:48,189:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:48,327:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:48,489:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:48,693:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:48,836:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:49,008:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:49,158:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:49,304:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:49,453:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:49,608:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:49,752:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:49,903:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:50,060:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:50,260:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:50,419:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:50,583:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:50,745:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:50,895:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:51,059:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:51,211:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:51,358:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:51,511:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:51,670:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:51,823:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:51,974:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:52,149:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:52,300:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:52,454:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:52,602:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:52,756:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:52,910:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:53,061:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:53,217:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:53,389:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:53,544:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:53,701:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:53,857:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:54,026:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:54,178:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:54,345:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:54,506:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:54,673:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:54,848:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:54,996:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:55,162:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:55,311:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:55,458:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:55,609:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:55,769:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:55,932:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:56,098:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:56,260:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:56,415:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:56,580:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:56,735:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:56,914:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:57,066:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:57,242:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:57,385:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:57,536:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 2024-08-16 22:11:57,691:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# Failed to log to Supabase:
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826517.5365763
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826517.3858442
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826517.242805
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826517.0662658
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826516.9148252
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826516.7355793
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826516.5801146
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826516.4154406
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826516.2605803
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826516.0987668
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826515.932996
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826515.7690995
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826515.6095057
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826515.4582608
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826515.3119714
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826515.1627874
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826514.9960144
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826514.8483953
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826514.6736763
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826514.5065346
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826514.3455167
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826514.1788542
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826514.0264978
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826513.8578558
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826513.7014856
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826513.5443637
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826513.3890982
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826513.2174232
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826513.0613537
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826512.9104557
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826512.7561493
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826512.602222
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826512.4548483
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826512.300399
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826512.1499836
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826511.9740381
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826511.8237822
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826511.6704376
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826511.5111344
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826511.358197
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826511.211026
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826511.0593264
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826510.8952384
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826510.7457154
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826510.5839472
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826510.419567
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826510.2604628
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826510.0602853
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826509.903833
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826509.7526753
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826509.6084895
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826509.4536092
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826509.304856
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826509.1581304
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826509.0085752
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826508.8369262
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826508.6934686
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826508.4898636
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826508.3273742
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826508.1897287
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826508.0255122
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826507.8578653
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826507.6793172
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826507.528258
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826507.3711047
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826507.2184796
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826507.061422
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826506.9002473
# {'level': 'INFO', 'message': 'HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# 1723826506.655634
# {'level': 'INFO', 'message': 'HTTP Request: GET https://api.gradio.app/pkg-version "HTTP/1.1 200 OK"', 'file_name': '/home/abinaya/.local/lib/python3.10/site-packages/httpx/_client.py'}
# HTTP Request: GET https://api.gradio.app/pkg-version "HTTP/1.1 200 OK"
# 1723826502.0897865

# %%
from supabase import create_client, Client

url = "https://qumfinzjetrdhzmbuwcz.supabase.co" #"your_supabase_url"
key = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6InF1bWZpbnpqZXRyZGh6bWJ1d2N6Iiwicm9sZSI6ImFub24iLCJpYXQiOjE3MjM3ODU2NTUsImV4cCI6MjAzOTM2MTY1NX0.e8SwMVAOEILIgWk4QaJu0STayCur7uyJEnMXBNUxadg" #"your_supabase_key"
supabase: Client = create_client(url, key)

data = {"level": "INFO", "message": "Test log entry", "file_name": "test.py"}
result = supabase.table("logs").insert(data).execute()
print(result)
# Out:
# 2024-08-16 21:48:17,052:INFO - HTTP Request: POST https://qumfinzjetrdhzmbuwcz.supabase.co/rest/v1/logs "HTTP/1.1 201 Created"
# data=[{'id': 1, 'timestamp': '2024-08-16T16:18:17.002576', 'level': 'INFO', 'message': 'Test log entry', 'file_name': 'test.py'}] count=None
